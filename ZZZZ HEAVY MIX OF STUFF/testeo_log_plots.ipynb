# %%
import numpy as np
times1 = np.load('times1.npy')
centros1=np.load('centros1.npy')
fwhms1=np.load('fwhms1.npy')

# %%
times2 = np.load('times2.npy')
centros2=np.load('centros2.npy')
fwhms2=np.load('fwhms2.npy')

# %%
times3 = np.load('times3.npy')
centros3=np.load('centros3.npy')
fwhms3=np.load('fwhms3.npy')

# %%
times4 = np.load('times4.npy')
centros4=np.load('centros4.npy')
fwhms4=np.load('fwhms4.npy')

times5 = np.load('times5.npy')
centros5=np.load('centros5.npy')
fwhms5=np.load('fwhms5.npy')

times6 = np.load('times6.npy')
centros6=np.load('centros6.npy')
fwhms6=np.load('fwhms6.npy')

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Enable LaTeX rendering
rcParams['text.usetex'] = True
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Computer Modern']  # Default LaTeX font

xi0 = -12 
t_max = 10
kappa_0 =4
# Subgráfico 2: FWHM en función del tiempo
closest_index_1 = np.abs(np.array(times1) - 9).argmin()
closest_index_2 = np.abs(np.array(times2) - 9).argmin()
closest_index_3 = np.abs(np.array(times3) - 9).argmin()


# Select all values before that index
times1 = times1[:closest_index_1]
fwhms1 = fwhms1 [:closest_index_1]
times2 = times2[:closest_index_2]
fwhms2 = fwhms2 [:closest_index_2]
times3 = times3[:closest_index_3]
fwhms3 = fwhms3 [:closest_index_3]


teo_fwhm = np.sqrt(1+((4/kappa_0)*times2)**2)/2
centros_teo = xi0 +2*times2
# plt.plot(times2, teo_fwhm, label=r'Analytical Solution', color='k', linestyle = '--')
plt.plot(times2, teo_fwhm, label=r'Analytical Solution', color='k', linestyle = '--')
# plt.plot(times, fwhms, label=r'$\kappa_{min}$ = 16', color='blue')
# plt.plot(times, fwhmsref, label=r'$\kappa_{min}$ = -16', color='green')
# plt.set_yscale('log')
# plt.plot(times2, fwhms2, label=r"Numerical Simulation", color='red')

dx = 40/(10000) 
C1 = (1/kappa_0)*(0.01/dx**2)
C2 = (1/kappa_0)*(0.005/dx**2)
C3 = (1/kappa_0)*(0.001/dx**2)

plt.plot(times1, fwhms1, label=rf"$C = {C1}$", color='green')
plt.plot(times3, fwhms3, label=rf"$C = {C2}$", color='red')
plt.plot(times2, fwhms2, label=rf"$C = {C3}$", color='blue')

# plt.plot(times5, fwhms5, label=r"$\Delta \tau = 0.0001$", color='green')
# plt.plot(times, np.abs(fwhmsref2-teo_fwhm), label="Evolución Libre", color='red')
# plt.axhline(y=2*b, color='k', linestyle='--', label='y = 2b')  # Línea en y = 2b




# plt.plot(times, recta, color='k', linestyle = '--', alpha = 1)
plt.xlabel(r"$\tau$", fontsize=30) 
plt.xlim(0, 9.25) 
plt.tick_params(axis='both', labelsize=25) 

# plt.ylim(0.7, 1.1) 
# plt.set_ylim(0.4, 0.8) 
# plt.axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  # Línea vertical en t2
# plt.axvline(x=t1, color='k', linestyle='--', label=f't = {t1}')  # Línea vertical en t1
plt.ylabel(r'$\Delta \xi$', fontsize=30, labelpad = 10)
# plt.yscale('log')
# plt.grid(True)
plt.legend(fontsize = 19.5)
plt.tick_params(axis='x', which='major', pad=10) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Enable LaTeX rendering
rcParams['text.usetex'] = True
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Computer Modern']  # Default LaTeX font

# Subgráfico 1: Centro en función del tiempo
# plt.plot(times, centros, label=r'$\kappa_{min}$ = 16', color='blue')
# plt.plot(times, centrosref, label=r'$\kappa_{min}$ = -16', color='green')
xi0 = -12 
t_max = 10
kappa_0 = 25
teo_speed = xi0+2*times1
plt.plot(times1, teo_speed, label=r"Analytical", color='k', linestyle = '--')
# plt.plot(times1, np.abs(centros1-teo_speed), label=r"Simulation", color='red')
# plt.plot(times2, np.abs(centros2-teo_speed), label=r"Simulation", color='red')
# plt.plot(times3, np.abs(centros3-teo_speed), label=r"Simulation", color='red')
plt.plot(times1, centros1, label=r"$\Delta \tau = 0.01$", color='blue')
plt.plot(times2, centros2, label=r"$\Delta \tau = 0.001$", color='green')
# plt.plot(times3, centros3, label=r"Simulation", color='red')
plt.xlabel(r"$\tau$", fontsize=26) 
plt.ylabel(r"$\left \langle \xi \right \rangle$", fontsize=26) 
# # plt.axhline(y=x1, color='k', linestyle='--')  
# # plt.axhline(y=x2, color='k', linestyle='--') 
# # plt.axhline(y=b, color='r', linestyle='-',alpha = 0.35  )  
# # plt.axhline(y=-b, color='r', linestyle='-', alpha = 0.35 )  
# # plt.axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  
# # plt.axvline(x=t1, color='k', linestyle='--', label=f't = {t2}')  
# # tpos, tneg = encontrar_abscisas_cercanas(centros, times, b)
# # plt.axvline(x=tpos, color='r', linestyle='-',alpha = 0.35)  
# # plt.axvline(x=tneg, color='r', linestyle='-',alpha = 0.35)  
# plt.set_xlabel(r"$\tau$", fontsize=16)
# plt.set_ylabel(r"$\left\langle x\right\rangle$", fontsize=16)
# plt.yscale ('log')
plt.xlim(0, 9)
# plt.ylim(0, 7.5)
plt.grid(True)
plt.legend()
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 20
#      16 plt.plot(times1, teo_speed, label=r"Analytical", color='k', linestyle = '--')
#      17 # plt.plot(times1, np.abs(centros1-teo_speed), label=r"Simulation", color='red')
#      18 # plt.plot(times2, np.abs(centros2-teo_speed), label=r"Simulation", color='red')
#      19 # plt.plot(times3, np.abs(centros3-teo_speed), label=r"Simulation", color='red')
# ---> 20 plt.plot(times1, centros1, label=r"$\Delta \tau = 0.01$", color='blue')
#      21 plt.plot(times2, centros2, label=r"$\Delta \tau = 0.001$", color='green')
#      22 # plt.plot(times3, centros3, label=r"Simulation", color='red')
#
# File ~/miniconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
# ...

# %%
# Subgráfico 2: FWHM en función del tiempo
teo_fwhm = np.sqrt(1+((4/kappa_0)*times1)**2)/2
# plt.plot(times1, np.abs(teo_fwhm-teo_fwhm), label=r'Analítico', color='k', linestyle = '--')
# plt.plot(times, fwhms, label=r'$\kappa_{min}$ = 16', color='blue')
# plt.plot(times, fwhmsref, label=r'$\kappa_{min}$ = -16', color='green')
# plt.set_yscale('log')
# plt.plot(times1, np.abs(fwhms1), label=r"$\Delta \tau = 0.01$", color='blue')
plt.plot(times6, np.abs(fwhms6-teo_fwhm), label=r"Medidas", color='red')
plt.plot(times4, np.abs(fwhms4-teo_fwhm), label=r"Sin Medidas", color='green')
# plt.plot(times, np.abs(fwhmsref2-teo_fwhm), label="Evolución Libre", color='red')
# plt.axhline(y=2*b, color='k', linestyle='--', label='y = 2b')  # Línea en y = 2b
plt.yscale ('log')



# plt.plot(times, recta, color='k', linestyle = '--', alpha = 1)
plt.xlabel(r"$\tau$", fontsize=26) 
plt.xlim(0, 9) 
# plt.ylim(0.47, 0.9) 
# plt.set_ylim(0.4, 0.8) 
# plt.axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  # Línea vertical en t2
# plt.axvline(x=t1, color='k', linestyle='--', label=f't = {t1}')  # Línea vertical en t1
plt.ylabel(r'$|\Delta \xi-\Delta \xi_{teo}|$', fontsize=26)
plt.grid(True)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Subgráfico 2: FWHM en función del tiempo
teo_fwhm = np.sqrt(1+((4/kappa_0)*times1)**2)/2
# plt.plot(times1, teo_fwhm, label=r'Analítico', color='k', linestyle = '--')
# plt.plot(times, fwhms, label=r'$\kappa_{min}$ = 16', color='blue')
# plt.plot(times, fwhmsref, label=r'$\kappa_{min}$ = -16', color='green')
# plt.set_yscale('log')
plt.plot(times1, np.abs(fwhms1-teo_fwhm), label=r"$\Delta \tau = 0.01$", color='blue')
plt.plot(times3, np.abs(fwhms3-teo_fwhm), label=r"$\Delta \tau = 0.05$", color='red')
plt.plot(times2, np.abs(fwhms2-teo_fwhm), label=r"$\Delta \tau = 0.001$", color='green')
plt.yscale('log')
# plt.plot(times, np.abs(fwhmsref2-teo_fwhm), label="Evolución Libre", color='red')
# plt.axhline(y=2*b, color='k', linestyle='--', label='y = 2b')  # Línea en y = 2b




# plt.plot(times, recta, color='k', linestyle = '--', alpha = 1)
plt.xlabel(r"$\tau$", fontsize=26) 
plt.xlim(0, 9) 
# plt.ylim(0.47, 0.9) 
# plt.set_ylim(0.4, 0.8) 
# plt.axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  # Línea vertical en t2
# plt.axvline(x=t1, color='k', linestyle='--', label=f't = {t1}')  # Línea vertical en t1
plt.ylabel(r'$\Delta \xi$', fontsize=26)
plt.grid(True)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kinetic_energies = np.load('kinetic_energies_1.npy')
potential_energies=np.load('pot_energies_1.npy')


kinetic_energies1 = np.load('kinetic_energies.npy')
potential_energies1=np.load('pot_energies.npy')

kinetic_energies2 = np.load('kinetic_energies_2.npy')
potential_energies2=np.load('pot_energies_2.npy')

kinetic_energies3 = np.load('kinetic_energies_3.npy')
potential_energies3=np.load('pot_energies_3.npy')

# %%
times = []
for i in range (len(kinetic_energies)):
    times.append (kinetic_energies[i][0])

kin_energies=[]
for i in range (len(kinetic_energies)):
    kin_energies.append(kinetic_energies[i][1])

pot_energies=[]
for i in range (len(potential_energies)):
    pot_energies.append(potential_energies[i][1])


T = kin_energies
V = pot_energies

print (len(times), len(kin_energies), len(pot_energies))
# Out:
# 299 299 299

# %%
times1 = []
for i in range (len(kinetic_energies1)):
    times1.append (kinetic_energies1[i][0])

kin_energies1=[]
for i in range (len(kinetic_energies1)):
    kin_energies1.append(kinetic_energies1[i][1])

pot_energies1=[]
for i in range (len(potential_energies1)):
    pot_energies1.append(potential_energies1[i][1])


T1 = kin_energies1
V1 = pot_energies1

# %%
times2 = []
for i in range (len(kinetic_energies2)):
    times2.append (kinetic_energies2[i][0])

kin_energies2=[]
for i in range (len(kinetic_energies2)):
    kin_energies2.append(kinetic_energies2[i][1])

pot_energies2=[]
for i in range (len(potential_energies2)):
    pot_energies2.append(potential_energies2[i][1])


T2 = kin_energies2
V2 = pot_energies2

# %%
times3 = []
for i in range (len(kinetic_energies3)):
    times3.append (kinetic_energies3[i][0])

kin_energies3=[]
for i in range (len(kinetic_energies3)):
    kin_energies3.append(kinetic_energies3[i][1])

pot_energies3=[]
for i in range (len(potential_energies3)):
    pot_energies3.append(potential_energies3[i][1])


T3 = kin_energies3
V3 = pot_energies3

# %%
import matplotlib.pyplot as plt
import numpy as np

times = np.array (times) 



T = np.array (T)
V = np.array(V)

T1 = np.array (T1)
V1 = np.array (V1)

T2 = np.array (T2)
V2 = np.array (V2)

T3 = np.array (T3)
V3 = np.array (V3)


    



plt.axhline (y = T[0]+V[0], linestyle = "--", color = 'k', alpha = 0.75) 
plt.plot(times, T+V, label=r'$\Delta \tau = 0.001$', color='green')
plt.plot(times2, T2+V2, label=r'$\Delta \tau = 0.0005$', color='red')
plt.plot(times3, T3+V3, label=r'$\Delta \tau = 0.0003$', color='blue')
# plt.plot(times1, T1+V1, label=r'$\Delta \tau = 0.0001$', color='green')
plt.xlabel(r'$\tau$', fontsize = 30)
plt.ylim(21.99, 22.033)
plt.xlim(0,8.75)
plt.ylabel(r'Total Energy', fontsize = 30, labelpad = 10)
plt.tick_params(axis='both', labelsize=25) 
# plt.grid(True)
plt.legend(loc = 'lower left', fontsize = 23)
plt.tick_params(axis='x', which='major', pad=10) 
plt.show()

# %%
import matplotlib.pyplot as plt

times = np.array (times) 


fig, axs = plt.subplots(3, 1, figsize=(10, 14))

T = np.array (T)
V = np.array(V)


plt.title 
# Subgráfico 1: Centro en función del tiempo
# Subgráfico 2: FWHM en función del tiempo
axs[0].plot(times, T+V, label='Energía', color='green')
# axs[0].axhline(y=2*b, color='k', linestyle='--', label='y = 2b')  # Línea en y = 2b
axs[0].set_xlabel('Tiempo t')
axs[0].set_ylim(21.75,22.15)
# axs[0].axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  # Línea vertical en t2
# axs[0].axvline(x=t1, color='k', linestyle='--', label=f't = {t1}')  # Línea vertical en t1
axs[0].set_ylabel('Energía')
axs[0].grid(True)
axs[0].legend()


# Subgráfico 2: POT
axs[1].plot(times, V, label='Energía', color='green')
# axs[1].axhline(y=2*b, color='k', linestyle='--', label='y = 2b')  # Línea en y = 2b
axs[1].set_xlabel('Tiempo t')
# axs[1].axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  # Línea vertical en t2
# axs[1].axvline(x=t1, color='k', linestyle='--', label=f't = {t1}')  # Línea vertical en t1
axs[1].set_ylabel('Energía')
axs[1].grid(True)
axs[1].legend()



# Subgráfico 3: Energía en función del tiempo
axs[2].plot(times, T, label='Energía', color='green')
# axs[2].axhline(y=2*b, color='k', linestyle='--', label='y = 2b')  # Línea en y = 2b
axs[2].set_xlabel('Tiempo t')
# axs[2].axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  # Línea vertical en t2
# axs[2].axvline(x=t1, color='k', linestyle='--', label=f't = {t1}')  # Línea vertical en t1
axs[2].set_ylabel('Energía')
axs[2].grid(True)
axs[2].legend()



# Ajustar el espacio entre los subgráficos
plt.tight_layout()

# Mostrar todos los subgráficos
plt.show()

# %%
centros = np.load ('centros.npy')

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Enable LaTeX rendering
rcParams['text.usetex'] = True
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Computer Modern']  # Default LaTeX font

# Subgráfico 1: Centro en función del tiempo
# plt.plot(times, centros, label=r'$\kappa_{min}$ = 16', color='blue')
# plt.plot(times, centrosref, label=r'$\kappa_{min}$ = -16', color='green')
xi0 = -12 
t_max = 10
kappa_0 = 25
teo_speed = xi0+2*times1
plt.plot(times1, teo_speed, label=r"Analytical", color='k', linestyle = '--')
# plt.plot(times1, np.abs(centros1-teo_speed), label=r"Simulation", color='red')
# plt.plot(times2, np.abs(centros2-teo_speed), label=r"Simulation", color='red')
# plt.plot(times3, np.abs(centros3-teo_speed), label=r"Simulation", color='red')
plt.plot(times1, centros, label=r"$\Delta \tau = 0.01$", color='blue')
# plt.plot(times3, centros3, label=r"Simulation", color='red')
plt.xlabel(r"$\tau$", fontsize=26) 
plt.ylabel(r"$\left \langle \xi \right \rangle$", fontsize=26) 
# # plt.axhline(y=x1, color='k', linestyle='--')  
# # plt.axhline(y=x2, color='k', linestyle='--') 
# # plt.axhline(y=b, color='r', linestyle='-',alpha = 0.35  )  
# # plt.axhline(y=-b, color='r', linestyle='-', alpha = 0.35 )  
# # plt.axvline(x=t2, color='k', linestyle='--', label=f't = {t2}')  
# # plt.axvline(x=t1, color='k', linestyle='--', label=f't = {t2}')  
# # tpos, tneg = encontrar_abscisas_cercanas(centros, times, b)
# # plt.axvline(x=tpos, color='r', linestyle='-',alpha = 0.35)  
# # plt.axvline(x=tneg, color='r', linestyle='-',alpha = 0.35)  
# plt.set_xlabel(r"$\tau$", fontsize=16)
# plt.set_ylabel(r"$\left\langle x\right\rangle$", fontsize=16)
# plt.yscale ('log')
plt.xlim(0, 9)
# plt.ylim(0, 7.5)
plt.grid(True)
plt.legend()
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 15
#      13 t_max = 10
#      14 kappa_0 = 25
# ---> 15 teo_speed = xi0+2*times1
#      16 plt.plot(times1, teo_speed, label=r"Analytical", color='k', linestyle = '--')
#      17 # plt.plot(times1, np.abs(centros1-teo_speed), label=r"Simulation", color='red')
#      18 # plt.plot(times2, np.abs(centros2-teo_speed), label=r"Simulation", color='red')
#      19 # plt.plot(times3, np.abs(centros3-teo_speed), label=r"Simulation", color='red')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'
